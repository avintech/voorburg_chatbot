# %% [markdown]
# Explore csv

# %%
import pandas as pd

# %%
df = pd.read_csv("papers-eng.csv")
df
# Out:
#       Year  Location        Format  \
# 0     2022    Ottawa         Video
# 1     2022    Ottawa         Paper
# 2     2022    Ottawa  Presentation
# 3     2022    Ottawa         Paper
# 4     2022    Ottawa  Presentation
# ...    ...       ...           ...
# 1639  2005  Helsinki         Paper
# 1640  2005  Helsinki  Presentation
# 1641  2005  Helsinki         Paper
# 1642  2005  Helsinki  Presentation
# 1643  2005  Helsinki  Presentation
#
#                                                   Title  \
# 0                  Welcome Remarks by Statistics Canada
# 1     The Value of Imports and Exports of Trade in G...
# 2     Call for collaboration: Trade asymmetries rese...
# 3     Singapore’s Experience in Developing Online Ma...
# 4     Singapore’s Experience in Developing Online Ma...
# ...                                                 ...
# 1639      UNSC Report on services statistics VG (paper)
# 1640  Use of administrative and Business Register (B...
# ...

# %%
filtered_df = df[df['Link'].str.endswith('.pdf', na=False)].reset_index(drop=True)
filtered_df
# Out:
#       Year  Location        Format  \
# 0     2022    Ottawa         Paper
# 1     2022    Ottawa  Presentation
# 2     2022    Ottawa         Paper
# 3     2022    Ottawa  Presentation
# 4     2022    Ottawa         Paper
# ...    ...       ...           ...
# 1527  2005  Helsinki         Paper
# 1528  2005  Helsinki  Presentation
# 1529  2005  Helsinki         Paper
# 1530  2005  Helsinki  Presentation
# 1531  2005  Helsinki  Presentation
#
#                                                   Title  \
# 0     The Value of Imports and Exports of Trade in G...
# 1     Call for collaboration: Trade asymmetries rese...
# 2     Singapore’s Experience in Developing Online Ma...
# 3     Singapore’s Experience in Developing Online Ma...
# 4                                Data Center Colocation
# ...                                                 ...
# 1527      UNSC Report on services statistics VG (paper)
# 1528  Use of administrative and Business Register (B...
# ...

# %% [markdown]
# Download PDFs

# %%
# Out:
# 1112
